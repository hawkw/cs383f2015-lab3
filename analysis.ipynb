# %% [markdown]
# El Farol Data Analysis
# ----------------------

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns
import pandas

# %%
# this doesn't currently work. fix later
# we don't really need interactive graphs for this.
#import plotly.plotly as ply
#import plotly.tools as tls
#from plotly.graph_objs import *
#py.sign_in("hawk", "uknav5itni")

# %%
runs100 = [ pandas.read_csv('results/elfarol-100agents-regression.csv'),
            pandas.read_csv('results/elfarol-100agents-random.csv'),
            pandas.read_csv('results/elfarol-100agents-average.csv'),
            pandas.read_csv('results/elfarol-100agents-markov.csv'),
            pandas.read_csv('results/elfarol-100agents-heterogenous.csv')]
df100 = pandas.concat(runs100, keys=['regression','random','averaging','markov','heterogenous'])

# %%
df100 = df100.reset_index(0)
df100.rename(columns={"level_0":"Run Type"}, inplace=True)
df100
# Out:
#          Run Type  Attending Count  tick
# 0      regression               43     1
# 1      regression               61     2
# 2      regression               76     3
# 3      regression               64     4
# 4      regression               87     5
# 5      regression               17     6
# 6      regression               32     7
# 7      regression               78     8
# 8      regression               69     9
# 9      regression               61    10
# 10     regression               85    11
# 11     regression               30    12
# 12     regression               36    13
# 13     regression               71    14
# 14     regression               75    15
# 15     regression               54    16
# 16     regression               84    17
# 17     regression               30    18
# 18     regression               32    19
# 19     regression               68    20
# 20     regression               79    21
# 21     regression               51    22
# 22     regression               82    23
# 23     regression               32    24
# 24     regression               27    25
# 25     regression               67    26
# 26     regression               83    27
# 27     regression               46    28
# 28     regression               82    29
# 29     regression               35    30
# ..            ...              ...   ...
# 270  heterogenous               40   271
# 271  heterogenous               46   272
# 272  heterogenous               99   273
# 273  heterogenous               73   274
# 274  heterogenous               74   275
# 275  heterogenous               47   276
# 276  heterogenous               38   277
# 277  heterogenous               45   278
# 278  heterogenous               55   279
# 279  heterogenous               62   280
# 280  heterogenous               97   281
# 281  heterogenous               66   282
# 282  heterogenous               40   283
# 283  heterogenous               44   284
# 284  heterogenous               48   285
# 285  heterogenous               70   286
# 286  heterogenous               58   287
# 287  heterogenous               91   288
# 288  heterogenous               46   289
# 289  heterogenous               46   290
# 290  heterogenous               22   291
# 291  heterogenous               55   292
# 292  heterogenous               80   293
# 293  heterogenous               84   294
# 294  heterogenous               83   295
# 295  heterogenous               48   296
# 296  heterogenous               42   297
# 297  heterogenous               23   298
# 298  heterogenous               60   299
# 299  heterogenous               61   300
#
# [1500 rows x 3 columns]

# %%
sns.lmplot(x='tick', y='Attending Count', data=df100, hue='Run Type')

# %%
g = sns.FacetGrid(df100, col="Run Type", col_wrap=2, margin_titles=True, size=7, hue="Run Type")
g.map(plt.scatter, "tick", "Attending Count")

# %%
runs1000 = [ pandas.read_csv('results/elfarol-1000agents-regression.csv'),
            pandas.read_csv('results/elfarol-1000agents-random.csv'),
            pandas.read_csv('results/elfarol-1000agents-average.csv'),
            pandas.read_csv('results/elfarol-1000agents-markov.csv')]
df1000 = pandas.concat(runs1000, keys=['regression','random','averaging','markov'])

# %%
df1000 = df1000.reset_index(0)
df1000.rename(columns={"level_0":"Run Type"}, inplace=True)
df1000
# Out:
#        Run Type  Attending Count  tick
# 0    regression              281     1
# 1    regression              117     2
# 2    regression              420     3
# 3    regression              214     4
# 4    regression              365     5
# 5    regression              405     6
# 6    regression              195     7
# 7    regression              133     8
# 8    regression              315     9
# 9    regression              120    10
# 10   regression              388    11
# 11   regression              429    12
# 12   regression              224    13
# 13   regression               43    14
# 14   regression              443    15
# 15   regression               69    16
# 16   regression              523    17
# 17   regression              634    18
# 18   regression              263    19
# 19   regression               31    20
# 20   regression              528    21
# 21   regression               91    22
# 22   regression              649    23
# 23   regression              618    24
# 24   regression              322    25
# 25   regression               37    26
# 26   regression              552    27
# 27   regression               83    28
# 28   regression              599    29
# 29   regression              640    30
# ..          ...              ...   ...
# 270      markov              477   271
# 271      markov               52   272
# 272      markov              442   273
# 273      markov              601   274
# 274      markov              508   275
# 275      markov               61   276
# 276      markov              483   277
# 277      markov               53   278
# 278      markov              432   279
# 279      markov              608   280
# 280      markov              517   281
# 281      markov               63   282
# 282      markov              488   283
# 283      markov               50   284
# 284      markov              429   285
# 285      markov              608   286
# 286      markov              531   287
# 287      markov               63   288
# 288      markov              486   289
# 289      markov               53   290
# 290      markov              412   291
# 291      markov              611   292
# 292      markov              542   293
# 293      markov               59   294
# 294      markov              492   295
# 295      markov               56   296
# 296      markov              400   297
# 297      markov              612   298
# 298      markov              551   299
# 299      markov               60   300
#
# [1111 rows x 3 columns]

# %%
g = sns.FacetGrid(df1000, col="Run Type", col_wrap=2, margin_titles=True, size=7, hue="Run Type")
g.map(plt.scatter, "tick", "Attending Count")

# %%
runs90t = [ pandas.read_csv('results/elfarol-100agents-threshold60-regression.csv'),
            pandas.read_csv('results/elfarol-100agents-threshold60-random.csv'),
            pandas.read_csv('results/elfarol-100agents-threshold60-average.csv'),
            pandas.read_csv('results/elfarol-000agents-threshold60-markov.csv')]
df60t = pandas.concat(runs90t, keys=['regression','random','averaging','markov'])
