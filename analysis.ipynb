# %% [markdown]
# El Farol Data Analysis
# ----------------------

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns
import pandas

# %%
# this doesn't currently work. fix later
# we don't really need interactive graphs for this.
#import plotly.plotly as ply
#import plotly.tools as tls
#from plotly.graph_objs import *
#py.sign_in("hawk", "uknav5itni")

# %%
runs100 = [ pandas.read_csv('results/elfarol-100agents-regression.csv'),
            pandas.read_csv('results/elfarol-100agents-random.csv'),
            pandas.read_csv('results/elfarol-100agents-average.csv'),
            pandas.read_csv('results/elfarol-100agents-markov.csv'),
            pandas.read_csv('results/elfarol-100agents-heterogenous.csv')]
df100 = pandas.concat(runs100, keys=['regression','random','averaging','markov','heterogenous'])

# %%
df100
# Out:
#                   Attending Count  tick
# regression   0                 43     1
#              1                 61     2
#              2                 76     3
#              3                 64     4
#              4                 87     5
#              5                 17     6
#              6                 32     7
#              7                 78     8
#              8                 69     9
#              9                 61    10
#              10                85    11
#              11                30    12
#              12                36    13
#              13                71    14
#              14                75    15
#              15                54    16
#              16                84    17
#              17                30    18
#              18                32    19
#              19                68    20
#              20                79    21
#              21                51    22
#              22                82    23
#              23                32    24
#              24                27    25
#              25                67    26
#              26                83    27
#              27                46    28
#              28                82    29
#              29                35    30
# ...                           ...   ...
# heterogenous 270               40   271
#              271               46   272
#              272               99   273
#              273               73   274
#              274               74   275
#              275               47   276
#              276               38   277
#              277               45   278
#              278               55   279
#              279               62   280
#              280               97   281
#              281               66   282
#              282               40   283
#              283               44   284
#              284               48   285
#              285               70   286
#              286               58   287
#              287               91   288
#              288               46   289
#              289               46   290
#              290               22   291
#              291               55   292
#              292               80   293
#              293               84   294
#              294               83   295
#              295               48   296
#              296               42   297
#              297               23   298
#              298               60   299
#              299               61   300
#
# [1500 rows x 2 columns]

# %%
sns.lmplot(x='tick', y='Attending Count', col='key', data=df100);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-0df0dfc7ef03> in <module>()
# ----> 1 sns.lmplot(x='tick', y='Attending Count', col='key', data=df100);
#
# /usr/local/Cellar/python3/3.4.1/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/seaborn/linearmodels.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, size, aspect, markers, sharex, sharey, hue_order, col_order, row_order, dropna, legend, legend_out, **kwargs)
#     768     need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     769     cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 770     data = data[cols]
#     771
#     772     # Initialize the grid
#
# /usr/local/Cellar/python3/3.4.1/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1772         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1773             # either boolean or fancy integer index
# -> 1774             return self._getitem_array(key)
#    1775         elif isinstance(key, DataFrame):
#    1776             return self._getitem_frame(key)
#
# /usr/local/Cellar/python3/3.4.1/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    1816             return self.take(indexer, axis=0, convert=False)
#    1817         else:
# -> 1818             indexer = self.ix._convert_to_indexer(key, axis=1)
#    1819             return self.take(indexer, axis=1, convert=True)
#    1820
#
# /usr/local/Cellar/python3/3.4.1/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1141                     if isinstance(obj, tuple) and is_setter:
#    1142                         return {'key': obj}
# -> 1143                     raise KeyError('%s not in index' % objarr[mask])
#    1144
#    1145                 return _values_from_object(indexer)
#
# KeyError: "['key'] not in index"

# %%
# Out:
# Index(['Attending Count', 'tick'], dtype='object')
